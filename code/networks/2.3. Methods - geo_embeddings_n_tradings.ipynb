# %%
import pandas as pd
import numpy as np
from node2vec import Node2Vec
from gensim.models import KeyedVectors
#from torch_geometric.nn import Node2Vec
from collections import defaultdict
from itertools import combinations
from sklearn.manifold import TSNE
import umap
import matplotlib.pyplot as plt
import seaborn as sns
from adjustText import adjust_text
from utils import *

READ_DATA_PATHS, WRITE_DATA_PATHS = resolve_paths(read_datasets=["Additional Data Sources - Country Borders", 
                                                                 "Additional Data Sources - CERDI Sea distance",
                                                                 "Additional Data Sources - Trading agreements",
                                                                 "Graphs Data",
                                                                 "Atlas Countries Data"], 
                                                write_datasets=["Graphs Data"])
# Out:
# Loading DATA_PATHS.yaml from ../../data/DATA_PATHS.yaml

# %% [markdown]
# ## Country borders (land)

# %%
G = parse_country_neighbors(READ_DATA_PATHS["Additional Data Sources - Country Borders"])

# %%
for i in nx.connected_components(G):
    print(i)
# Out:
# {'NOR', 'LBY', 'SWZ', 'SSD', 'NGA', 'IRN', 'EST', 'LBR', 'ESH', 'BLR', 'VAT', 'MNE', 'KGZ', 'AUT', 'BGD', 'TZA', 'SDN', 'TUN', 'TJK', 'CZE', 'HRV', 'JOR', 'MAR', 'GAB', 'MMR', 'UGA', 'ROU', 'GIB', 'BDI', 'FRA', 'GHA', 'TCD', 'OMN', 'SAU', 'TGO', 'UZB', 'LSO', 'MCO', 'VNM', 'AFG', 'DZA', 'NLD', 'SEN', 'ARM', 'IND', 'CIV', 'KWT', 'MOZ', 'DNK', 'LTU', 'SVN', 'SMR', 'BTN', 'PAK', 'ITA', 'HUN', 'THA', 'IDN', 'SRB', 'GNB', 'NAM', 'LAO', 'MDA', 'POL', 'ALB', 'BEN', 'TUR', 'GRC', 'RUS', 'LBN', 'NER', 'CAF', 'MYS', 'ETH', 'KHM', 'LIE', 'ISR', 'XKX', 'FIN', 'BFA', 'PNG', 'ESP', 'CHE', 'MRT', 'MNG', 'MKD', 'TLS', 'KAZ', 'PSE', 'PRK', 'BEL', 'CMR', 'ARE', 'TKM', 'DJI', 'SCG', 'AGO', 'PRT', 'ZWE', 'GNQ', 'SWE', 'EGY', 'IRQ', 'LUX', 'MLI', 'BWA', 'NPL', 'GMB', 'QAT', 'AND', 'ERI', 'ZAF', 'DEU', 'UKR', 'GIN', 'AZE', 'KOR', 'BIH', 'KEN', 'RWA', 'SVK', 'CHN', 'ZMB', 'MWI', 'BGR', 'BRN', 'COG', 'SLE', 'YEM', 'SOM', 'LVA', 'COD', 'GEO', 'SYR'}
# {'BRA', 'PRY', 'HND', 'PAN', 'BLZ', 'COL', 'VEN', 'ARG', 'MEX', 'GTM', 'USA', 'SLV', 'PER', 'CUB', 'GUF', 'NIC', 'BOL', 'SUR', 'CAN', 'CHL', 'URY', 'ECU', 'CRI', 'GUY'}
# {'DOM', 'HTI'}
# {'IRL', 'GBR'}
# {'SXM', 'MAF'}
# {'ANT', 'GLP'}

# %% [markdown]
# ## Country borders (maritime)

# %%
maritime = pd.read_excel(READ_DATA_PATHS["Additional Data Sources - CERDI Sea distance"])[["iso1", "iso2", "seadistance"]]
maritime = maritime[maritime.seadistance > 0]

# %%
maritime.loc[:, "weights"] = maritime_distance_to_weight(maritime.loc[:, "seadistance"])

# %%
maritime.head()

# %%
maritime.describe()

# %%
already_added = set()
for ix, row in maritime.iterrows():
    # The edge from maritime distances
    edge = (min(row["iso1"], row["iso2"]), max(row["iso1"], row["iso2"]))
    # If already added, skip
    if edge in already_added:
        continue
    # If not added, and not a border country, add it
    elif not G.has_edge(row["iso1"], row["iso2"]):
        G.add_edge(row["iso1"], row["iso2"], weight=row["weights"])
    # If already a border country, but also a maritime connection, add to the weight
    else:
        G[row["iso1"]][row["iso2"]]["weight"] += row["weights"]
    already_added.add(edge)

# %%
for i in nx.connected_components(G):
    print(i)

# %%
largest_cc = max(nx.connected_components(G), key=len)
nx.diameter(G.subgraph(largest_cc).copy())

# %%
# Node2Vec 
node2vec = Node2Vec(G, dimensions=8, walk_length=10, num_walks=200, p=1, q=1, weight_key='weight', workers=4)
model = node2vec.fit(window=4, min_count=1, batch_words=4)

# %%
model.wv['ARG']  # get embedding for a country
model.wv.most_similar('COD', topn=20)  # find nearest countries

# %%
# Save embeddings
model.wv.save_word2vec_format(WRITE_DATA_PATHS["Graphs Data"] + "/geo-embeddings.vec")  # save

# %% [markdown]
# ## Visualization

# %% [markdown]
# Note on UMAP Reproducibility <br>
# (https://umap-learn.readthedocs.io/en/latest/reproducibility.html) <br>
# UMAP is a stochastic algorithm – it makes use of randomness both to speed up approximation steps, and to aid in solving hard optimization problems. This means that different runs of UMAP can produce different results. UMAP is relatively stable – thus the variance between runs should ideally be relatively small – but different runs may have variations none the less. To ensure that results can be reproduced exactly UMAP allows the user to set a random seed state. <br>
#
# Since version 0.4 UMAP also support multi-threading for faster performance; when performing optimization this exploits the fact that race conditions between the threads are acceptable within certain optimization phases. Unfortunately this means that the randomness in UMAP outputs for the multi-threaded case depends not only on the random seed input, but also on race conditions between threads during optimization, over which no control can be had. This means that multi-threaded UMAP results cannot be explicitly reproduced.

# %%
# Re.load embeddings
model = KeyedVectors.load_word2vec_format(READ_DATA_PATHS["Graphs Data"] + "/geo-embeddings.vec", binary=False)

# Get list of country names and their vectors
countries = list(model.wv.vocab.keys())
vectors = np.array([model.wv[c] for c in countries])

reducer = umap.UMAP(n_neighbors=5, min_dist=0.9)
vectors_2d = reducer.fit_transform(vectors)
# Out:
# C:\Users\ginof\AppData\Local\Temp\ipykernel_21528\3435202134.py:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   countries = list(model.wv.vocab.keys())
# C:\Users\ginof\AppData\Local\Temp\ipykernel_21528\3435202134.py:9: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   vectors = np.array([model.wv[c] for c in countries])
# c:\Users\ginof\anaconda3\envs\thesis\lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
fig, ax = plt.subplots(figsize=(14, 10), dpi=300)

sns.scatterplot(x=vectors_2d[:, 0], y=vectors_2d[:, 1], alpha=0.6, ax=ax)

# Create all text labels
texts = [
    plt.text(vectors_2d[i, 0], vectors_2d[i, 1], country, fontsize=8)
    for i, country in enumerate(countries)
]

plt.xlabel("Dimension 1", fontsize=14, fontweight='bold')
plt.ylabel("Dimension 2", fontsize=14, fontweight='bold')
plt.grid(True)
plt.tight_layout()
# Auto-adjust to avoid overlap
adjust_text(texts, #expand=(2, 2), # expand text bounding boxes by 1.2 fold in x direction and 2 fold in y direction
            arrowprops=dict(arrowstyle='->', color='gray', lw=0.5), # ensure the labeling is clear by adding arrows
            force_text=(3, 3));
plt.show()

# %% [markdown]
# ### Trading agreements

# %%
trading_agreements = pd.read_excel(READ_DATA_PATHS["Additional Data Sources - Trading agreements"])

# %%
trading_agreements["In-force Status"].unique()
# Out:
# array(['in force', 'unknown', 'expired', nan, 'signed - not yet in force'],
#       dtype=object)

# %%
trading_agreements = trading_agreements[trading_agreements["In-force Status"] == 'in force']

# %%
trading_agreements["Date of Signature"] = pd.to_datetime(trading_agreements["Date of Signature"], format="%d %b %Y")
trading_agreements["Date of Entry into Force"] = pd.to_datetime(trading_agreements["Date of Entry into Force"], format="%d %b %Y")

# %%
trading_agreements[trading_agreements["Date of Entry into Force"] > pd.to_datetime("2012-01-01")]

# %%
trading_agreements.Membership.str.split(";")

# %%
countries_map = pd.read_csv(READ_DATA_PATHS["Atlas Countries Data"], encoding="latin1")

# %%
# Initialize a dict for edge weights
edge_weights = defaultdict(int)

# Iterate over each agreement
for row in trading_agreements.Membership:  # in case of NaNs
    countries = [c.strip() for c in row.split(';')]
    # Add edges for each pair (undirected)
    for c1, c2 in combinations(sorted(countries), 2):
        edge_weights[(c1, c2)] += 1

# %%
edge_weights
# Out:
# defaultdict(int,
#             {('Algeria', 'Angola'): 1,
#              ('Algeria', 'Benin'): 2,
#              ('Algeria', 'Botswana'): 1,
#              ('Algeria', 'Burkina Faso'): 1,
#              ('Algeria', 'Burundi'): 1,
#              ('Algeria', 'Cabo Verde'): 1,
#              ('Algeria', 'Cameroon'): 2,
#              ('Algeria', 'Central African Republic'): 1,
#              ('Algeria', 'Chad'): 1,
#              ('Algeria', 'Comoros'): 1,
#              ('Algeria', 'Congo'): 1,
#              ('Algeria', "Cote d'Ivoire"): 1,
#              ('Algeria', 'Djibouti'): 1,
#              ('Algeria', 'Egypt'): 3,
#              ('Algeria', 'Equatorial Guinea'): 1,
#              ('Algeria', 'Ethiopia'): 1,
#              ('Algeria', 'Gabon'): 1,
#              ('Algeria', 'Gambia'): 1,
#              ('Algeria', 'Ghana'): 2,
#              ('Algeria', 'Guinea'): 2,
#              ('Algeria', 'Guinea-Bissau'): 1,
#              ('Algeria', 'Kenya'): 1,
#              ('Algeria', 'Lesotho'): 1,
#              ('Algeria', 'Liberia'): 1,
#              ('Algeria', 'Libya'): 4,
#              ('Algeria', 'Madagascar'): 1,
#              ('Algeria', 'Malawi'): 1,
#              ('Algeria', 'Mali'): 1,
#              ('Algeria', 'Mauritania'): 2,
#              ('Algeria', 'Mauritius'): 1,
#              ('Algeria', 'Mozambique'): 2,
#              ('Algeria', 'Namibia'): 1,
#              ('Algeria', 'Niger'): 1,
#              ('Algeria', 'Nigeria'): 2,
#              ('Algeria', 'Rwanda'): 1,
#              ('Algeria', 'Sao Tome and Principe'): 1,
#              ('Algeria', 'Senegal'): 1,
#              ('Algeria', 'Seychelles'): 1,
#              ('Algeria', 'Sierra Leone'): 1,
#              ('Algeria', 'Somalia'): 1,
#              ('Algeria', 'Sudan'): 3,
#              ('Algeria', 'Togo'): 1,
#              ('Algeria', 'Tunisia'): 4,
#              ('Algeria', 'Uganda'): 1,
#              ('Algeria', 'United Republic of Tanzania'): 2,
#              ('Algeria', 'Zambia'): 1,
#              ('Algeria', 'Zimbabwe'): 2,
#              ('Angola', 'Benin'): 1,
#              ('Angola', 'Botswana'): 3,
#              ('Angola', 'Burkina Faso'): 1,
#              ('Angola', 'Burundi'): 3,
#              ('Angola', 'Cabo Verde'): 1,
#              ('Angola', 'Cameroon'): 2,
#              ('Angola', 'Central African Republic'): 2,
#              ('Angola', 'Chad'): 2,
#              ('Angola', 'Comoros'): 2,
#              ('Angola', 'Congo'): 3,
#              ('Angola', "Cote d'Ivoire"): 1,
#              ('Angola', 'Djibouti'): 2,
#              ('Angola', 'Egypt'): 2,
#              ('Angola', 'Equatorial Guinea'): 2,
#              ('Angola', 'Ethiopia'): 2,
#              ('Angola', 'Gabon'): 2,
#              ('Angola', 'Gambia'): 1,
#              ('Angola', 'Ghana'): 1,
#              ('Angola', 'Guinea'): 1,
#              ('Angola', 'Guinea-Bissau'): 1,
#              ('Angola', 'Kenya'): 2,
#              ('Angola', 'Lesotho'): 3,
#              ('Angola', 'Liberia'): 1,
#              ('Angola', 'Libya'): 1,
#              ('Angola', 'Madagascar'): 2,
#              ('Angola', 'Malawi'): 4,
#              ('Angola', 'Mali'): 1,
#              ('Angola', 'Mauritania'): 1,
#              ('Angola', 'Mauritius'): 4,
#              ('Angola', 'Mozambique'): 3,
#              ('Angola', 'Namibia'): 4,
#              ('Angola', 'Niger'): 1,
#              ('Angola', 'Nigeria'): 1,
#              ('Angola', 'Rwanda'): 3,
#              ('Angola', 'Sao Tome and Principe'): 2,
#              ('Angola', 'Senegal'): 1,
#              ('Angola', 'Seychelles'): 3,
#              ('Angola', 'Sierra Leone'): 1,
#              ('Angola', 'Somalia'): 1,
#              ('Angola', 'Sudan'): 2,
#              ('Angola', 'Togo'): 1,
#              ('Angola', 'Tunisia'): 1,
#              ('Angola', 'Uganda'): 2,
#              ('Angola', 'United Republic of Tanzania'): 4,
#              ('Angola', 'Zambia'): 4,
#              ('Angola', 'Zimbabwe'): 4,
#              ('Benin', 'Botswana'): 1,
#              ('Benin', 'Burkina Faso'): 3,
#              ('Benin', 'Burundi'): 1,
#              ('Benin', 'Cabo Verde'): 2,
#              ('Benin', 'Cameroon'): 2,
#              ('Benin', 'Central African Republic'): 1,
#              ('Benin', 'Chad'): 1,
#              ('Benin', 'Comoros'): 1,
#              ('Benin', 'Congo'): 1,
#              ('Benin', "Cote d'Ivoire"): 3,
#              ('Benin', 'Djibouti'): 1,
#              ('Benin', 'Egypt'): 2,
#              ('Benin', 'Equatorial Guinea'): 1,
#              ('Benin', 'Ethiopia'): 1,
#              ('Benin', 'Gabon'): 1,
#              ('Benin', 'Gambia'): 2,
#              ('Benin', 'Ghana'): 3,
#              ('Benin', 'Guinea'): 3,
#              ('Benin', 'Guinea-Bissau'): 2,
#              ('Benin', 'Kenya'): 1,
#              ('Benin', 'Lesotho'): 1,
#              ('Benin', 'Liberia'): 2,
#              ('Benin', 'Libya'): 2,
#              ('Benin', 'Madagascar'): 1,
#              ('Benin', 'Malawi'): 1,
#              ('Benin', 'Mali'): 3,
#              ('Benin', 'Mauritania'): 1,
#              ('Benin', 'Mauritius'): 1,
#              ('Benin', 'Mozambique'): 2,
#              ('Benin', 'Namibia'): 1,
#              ('Benin', 'Niger'): 3,
#              ('Benin', 'Nigeria'): 3,
#              ('Benin', 'Rwanda'): 1,
#              ('Benin', 'Sao Tome and Principe'): 1,
#              ('Benin', 'Senegal'): 3,
#              ('Benin', 'Seychelles'): 1,
#              ('Benin', 'Sierra Leone'): 2,
#              ('Benin', 'Somalia'): 1,
#              ('Benin', 'Sudan'): 2,
#              ('Benin', 'Togo'): 3,
#              ('Benin', 'Tunisia'): 2,
#              ('Benin', 'Uganda'): 1,
#              ('Benin', 'United Republic of Tanzania'): 2,
#              ('Benin', 'Zambia'): 1,
#              ('Benin', 'Zimbabwe'): 2,
#              ('Botswana', 'Burkina Faso'): 1,
#              ('Botswana', 'Burundi'): 1,
#              ('Botswana', 'Cabo Verde'): 1,
#              ('Botswana', 'Cameroon'): 1,
#              ('Botswana', 'Central African Republic'): 1,
#              ('Botswana', 'Chad'): 1,
#              ('Botswana', 'Comoros'): 1,
#              ('Botswana', 'Congo'): 2,
#              ('Botswana', "Cote d'Ivoire"): 1,
#              ('Botswana', 'Djibouti'): 1,
#              ('Botswana', 'Egypt'): 1,
#              ('Botswana', 'Equatorial Guinea'): 1,
#              ('Botswana', 'Ethiopia'): 1,
#              ('Botswana', 'Gabon'): 1,
#              ('Botswana', 'Gambia'): 1,
#              ('Botswana', 'Ghana'): 1,
#              ('Botswana', 'Guinea'): 1,
#              ('Botswana', 'Guinea-Bissau'): 1,
#              ('Botswana', 'Kenya'): 1,
#              ('Botswana', 'Lesotho'): 5,
#              ('Botswana', 'Liberia'): 1,
#              ('Botswana', 'Libya'): 1,
#              ('Botswana', 'Madagascar'): 1,
#              ('Botswana', 'Malawi'): 3,
#              ('Botswana', 'Mali'): 1,
#              ('Botswana', 'Mauritania'): 1,
#              ('Botswana', 'Mauritius'): 3,
#              ('Botswana', 'Mozambique'): 3,
#              ('Botswana', 'Namibia'): 5,
#              ('Botswana', 'Niger'): 1,
#              ('Botswana', 'Nigeria'): 1,
#              ('Botswana', 'Rwanda'): 1,
#              ('Botswana', 'Sao Tome and Principe'): 1,
#              ('Botswana', 'Senegal'): 1,
#              ('Botswana', 'Seychelles'): 2,
#              ('Botswana', 'Sierra Leone'): 1,
#              ('Botswana', 'Somalia'): 1,
#              ('Botswana', 'Sudan'): 1,
#              ('Botswana', 'Togo'): 1,
#              ('Botswana', 'Tunisia'): 1,
#              ('Botswana', 'Uganda'): 1,
#              ('Botswana', 'United Republic of Tanzania'): 3,
#              ('Botswana', 'Zambia'): 3,
#              ('Botswana', 'Zimbabwe'): 3,
#              ('Burkina Faso', 'Burundi'): 1,
#              ('Burkina Faso', 'Cabo Verde'): 2,
#              ('Burkina Faso', 'Cameroon'): 1,
#              ('Burkina Faso', 'Central African Republic'): 1,
#              ('Burkina Faso', 'Chad'): 1,
#              ('Burkina Faso', 'Comoros'): 1,
#              ('Burkina Faso', 'Congo'): 1,
#              ('Burkina Faso', "Cote d'Ivoire"): 3,
#              ('Burkina Faso', 'Djibouti'): 1,
#              ('Burkina Faso', 'Egypt'): 1,
#              ('Burkina Faso', 'Equatorial Guinea'): 1,
#              ('Burkina Faso', 'Ethiopia'): 1,
#              ('Burkina Faso', 'Gabon'): 1,
#              ('Burkina Faso', 'Gambia'): 2,
#              ('Burkina Faso', 'Ghana'): 2,
#              ('Burkina Faso', 'Guinea'): 2,
#              ('Burkina Faso', 'Guinea-Bissau'): 2,
#              ('Burkina Faso', 'Kenya'): 1,
#              ('Burkina Faso', 'Lesotho'): 1,
#              ('Burkina Faso', 'Liberia'): 2,
#              ('Burkina Faso', 'Libya'): 1,
#              ('Burkina Faso', 'Madagascar'): 1,
#              ('Burkina Faso', 'Malawi'): 1,
#              ('Burkina Faso', 'Mali'): 3,
#              ('Burkina Faso', 'Mauritania'): 1,
#              ('Burkina Faso', 'Mauritius'): 1,
#              ('Burkina Faso', 'Mozambique'): 1,
#              ('Burkina Faso', 'Namibia'): 1,
#              ('Burkina Faso', 'Niger'): 3,
#              ('Burkina Faso', 'Nigeria'): 2,
#              ('Burkina Faso', 'Rwanda'): 1,
#              ('Burkina Faso', 'Sao Tome and Principe'): 1,
#              ('Burkina Faso', 'Senegal'): 3,
#              ('Burkina Faso', 'Seychelles'): 1,
#              ('Burkina Faso', 'Sierra Leone'): 2,
#              ('Burkina Faso', 'Somalia'): 1,
#              ('Burkina Faso', 'Sudan'): 1,
#              ('Burkina Faso', 'Togo'): 3,
#              ('Burkina Faso', 'Tunisia'): 1,
#              ('Burkina Faso', 'Uganda'): 1,
#              ('Burkina Faso', 'United Republic of Tanzania'): 1,
#              ('Burkina Faso', 'Zambia'): 1,
#              ('Burkina Faso', 'Zimbabwe'): 1,
#              ('Burundi', 'Cabo Verde'): 1,
#              ('Burundi', 'Cameroon'): 2,
#              ('Burundi', 'Central African Republic'): 2,
#              ('Burundi', 'Chad'): 2,
#              ('Burundi', 'Comoros'): 2,
#              ('Burundi', 'Congo'): 2,
#              ('Burundi', "Cote d'Ivoire"): 1,
#              ('Burundi', 'Djibouti'): 2,
#              ('Burundi', 'Egypt'): 2,
#              ('Burundi', 'Equatorial Guinea'): 2,
#              ('Burundi', 'Ethiopia'): 2,
#              ('Burundi', 'Gabon'): 2,
#              ('Burundi', 'Gambia'): 1,
#              ('Burundi', 'Ghana'): 1,
#              ('Burundi', 'Guinea'): 1,
#              ('Burundi', 'Guinea-Bissau'): 1,
#              ('Burundi', 'Kenya'): 3,
#              ('Burundi', 'Lesotho'): 1,
#              ('Burundi', 'Liberia'): 1,
#              ('Burundi', 'Libya'): 1,
#              ('Burundi', 'Madagascar'): 2,
#              ('Burundi', 'Malawi'): 2,
#              ('Burundi', 'Mali'): 1,
#              ('Burundi', 'Mauritania'): 1,
#              ('Burundi', 'Mauritius'): 2,
#              ('Burundi', 'Mozambique'): 1,
#              ('Burundi', 'Namibia'): 2,
#              ('Burundi', 'Niger'): 1,
#              ('Burundi', 'Nigeria'): 1,
#              ('Burundi', 'Rwanda'): 5,
#              ('Burundi', 'Sao Tome and Principe'): 2,
#              ('Burundi', 'Senegal'): 1,
#              ('Burundi', 'Seychelles'): 2,
#              ('Burundi', 'Sierra Leone'): 1,
#              ('Burundi', 'Somalia'): 1,
#              ('Burundi', 'Sudan'): 2,
#              ('Burundi', 'Togo'): 1,
#              ('Burundi', 'Tunisia'): 1,
#              ('Burundi', 'Uganda'): 3,
#              ('Burundi', 'United Republic of Tanzania'): 3,
#              ('Burundi', 'Zambia'): 2,
#              ('Burundi', 'Zimbabwe'): 2,
#              ('Cabo Verde', 'Cameroon'): 1,
#              ('Cabo Verde', 'Central African Republic'): 1,
#              ('Cabo Verde', 'Chad'): 1,
#              ('Cabo Verde', 'Comoros'): 1,
#              ('Cabo Verde', 'Congo'): 1,
#              ('Cabo Verde', "Cote d'Ivoire"): 2,
#              ('Cabo Verde', 'Djibouti'): 1,
#              ('Cabo Verde', 'Egypt'): 1,
#              ('Cabo Verde', 'Equatorial Guinea'): 1,
#              ('Cabo Verde', 'Ethiopia'): 1,
#              ('Cabo Verde', 'Gabon'): 1,
#              ('Cabo Verde', 'Gambia'): 2,
#              ('Cabo Verde', 'Ghana'): 2,
#              ('Cabo Verde', 'Guinea'): 2,
#              ('Cabo Verde', 'Guinea-Bissau'): 2,
#              ('Cabo Verde', 'Kenya'): 1,
#              ('Cabo Verde', 'Lesotho'): 1,
#              ('Cabo Verde', 'Liberia'): 2,
#              ('Cabo Verde', 'Libya'): 1,
#              ('Cabo Verde', 'Madagascar'): 1,
#              ('Cabo Verde', 'Malawi'): 1,
#              ('Cabo Verde', 'Mali'): 2,
#              ('Cabo Verde', 'Mauritania'): 1,
#              ('Cabo Verde', 'Mauritius'): 1,
#              ('Cabo Verde', 'Mozambique'): 1,
#              ('Cabo Verde', 'Namibia'): 1,
#              ('Cabo Verde', 'Niger'): 2,
#              ('Cabo Verde', 'Nigeria'): 2,
#              ('Cabo Verde', 'Rwanda'): 1,
#              ('Cabo Verde', 'Sao Tome and Principe'): 1,
#              ('Cabo Verde', 'Senegal'): 2,
#              ('Cabo Verde', 'Seychelles'): 1,
#              ('Cabo Verde', 'Sierra Leone'): 2,
#              ('Cabo Verde', 'Somalia'): 1,
#              ('Cabo Verde', 'Sudan'): 1,
#              ('Cabo Verde', 'Togo'): 2,
#              ('Cabo Verde', 'Tunisia'): 1,
#              ('Cabo Verde', 'Uganda'): 1,
#              ('Cabo Verde', 'United Republic of Tanzania'): 1,
#              ('Cabo Verde', 'Zambia'): 1,
#              ('Cabo Verde', 'Zimbabwe'): 1,
#              ('Cameroon', 'Central African Republic'): 3,
#              ('Cameroon', 'Chad'): 3,
#              ('Cameroon', 'Comoros'): 1,
#              ('Cameroon', 'Congo'): 2,
#              ('Cameroon', "Cote d'Ivoire"): 1,
#              ('Cameroon', 'Djibouti'): 1,
#              ('Cameroon', 'Egypt'): 2,
#              ('Cameroon', 'Equatorial Guinea'): 3,
#              ('Cameroon', 'Ethiopia'): 1,
#              ('Cameroon', 'Gabon'): 3,
#              ('Cameroon', 'Gambia'): 1,
#              ('Cameroon', 'Ghana'): 2,
#              ('Cameroon', 'Guinea'): 2,
#              ('Cameroon', 'Guinea-Bissau'): 1,
#              ('Cameroon', 'Kenya'): 1,
#              ('Cameroon', 'Lesotho'): 1,
#              ('Cameroon', 'Liberia'): 1,
#              ('Cameroon', 'Libya'): 2,
#              ('Cameroon', 'Madagascar'): 1,
#              ('Cameroon', 'Malawi'): 1,
#              ('Cameroon', 'Mali'): 1,
#              ('Cameroon', 'Mauritania'): 1,
#              ('Cameroon', 'Mauritius'): 1,
#              ('Cameroon', 'Mozambique'): 2,
#              ('Cameroon', 'Namibia'): 1,
#              ('Cameroon', 'Niger'): 1,
#              ('Cameroon', 'Nigeria'): 2,
#              ('Cameroon', 'Rwanda'): 2,
#              ('Cameroon', 'Sao Tome and Principe'): 2,
#              ('Cameroon', 'Senegal'): 1,
#              ('Cameroon', 'Seychelles'): 1,
#              ('Cameroon', 'Sierra Leone'): 1,
#              ('Cameroon', 'Somalia'): 1,
#              ('Cameroon', 'Sudan'): 2,
#              ('Cameroon', 'Togo'): 1,
#              ('Cameroon', 'Tunisia'): 2,
#              ('Cameroon', 'Uganda'): 1,
#              ('Cameroon', 'United Republic of Tanzania'): 2,
#              ('Cameroon', 'Zambia'): 1,
#              ('Cameroon', 'Zimbabwe'): 2,
#              ('Central African Republic', 'Chad'): 3,
#              ('Central African Republic', 'Comoros'): 1,
#              ('Central African Republic', 'Congo'): 2,
#              ('Central African Republic', "Cote d'Ivoire"): 1,
#              ('Central African Republic', 'Djibouti'): 1,
#              ('Central African Republic', 'Egypt'): 1,
#              ('Central African Republic', 'Equatorial Guinea'): 3,
#              ('Central African Republic', 'Ethiopia'): 1,
#              ('Central African Republic', 'Gabon'): 3,
#              ('Central African Republic', 'Gambia'): 1,
#              ('Central African Republic', 'Ghana'): 1,
#              ('Central African Republic', 'Guinea'): 1,
#              ('Central African Republic', 'Guinea-Bissau'): 1,
#              ('Central African Republic', 'Kenya'): 1,
#              ('Central African Republic', 'Lesotho'): 1,
#              ('Central African Republic', 'Liberia'): 1,
#              ('Central African Republic', 'Libya'): 1,
#              ('Central African Republic', 'Madagascar'): 1,
#              ('Central African Republic', 'Malawi'): 1,
#              ('Central African Republic', 'Mali'): 1,
#              ('Central African Republic', 'Mauritania'): 1,
#              ('Central African Republic', 'Mauritius'): 1,
#              ('Central African Republic', 'Mozambique'): 1,
#              ('Central African Republic', 'Namibia'): 1,
#              ('Central African Republic', 'Niger'): 1,
#              ('Central African Republic', 'Nigeria'): 1,
#              ('Central African Republic', 'Rwanda'): 2,
#              ('Central African Republic', 'Sao Tome and Principe'): 2,
#              ('Central African Republic', 'Senegal'): 1,
#              ('Central African Republic', 'Seychelles'): 1,
#              ('Central African Republic', 'Sierra Leone'): 1,
#              ('Central African Republic', 'Somalia'): 1,
#              ('Central African Republic', 'Sudan'): 1,
#              ('Central African Republic', 'Togo'): 1,
#              ('Central African Republic', 'Tunisia'): 1,
#              ('Central African Republic', 'Uganda'): 1,
#              ('Central African Republic', 'United Republic of Tanzania'): 1,
#              ('Central African Republic', 'Zambia'): 1,
#              ('Central African Republic', 'Zimbabwe'): 1,
#              ('Chad', 'Comoros'): 1,
#              ('Chad', 'Congo'): 2,
#              ('Chad', "Cote d'Ivoire"): 1,
#              ('Chad', 'Djibouti'): 1,
#              ('Chad', 'Egypt'): 1,
#              ('Chad', 'Equatorial Guinea'): 3,
#              ('Chad', 'Ethiopia'): 1,
#              ('Chad', 'Gabon'): 3,
#              ('Chad', 'Gambia'): 1,
#              ('Chad', 'Ghana'): 1,
#              ('Chad', 'Guinea'): 1,
#              ('Chad', 'Guinea-Bissau'): 1,
#              ('Chad', 'Kenya'): 1,
#              ('Chad', 'Lesotho'): 1,
#              ('Chad', 'Liberia'): 1,
#              ('Chad', 'Libya'): 1,
#              ('Chad', 'Madagascar'): 1,
#              ('Chad', 'Malawi'): 1,
#              ('Chad', 'Mali'): 1,
#              ('Chad', 'Mauritania'): 1,
#              ('Chad', 'Mauritius'): 1,
#              ('Chad', 'Mozambique'): 1,
#              ('Chad', 'Namibia'): 1,
#              ('Chad', 'Niger'): 1,
#              ('Chad', 'Nigeria'): 1,
#              ('Chad', 'Rwanda'): 2,
#              ('Chad', 'Sao Tome and Principe'): 2,
#              ('Chad', 'Senegal'): 1,
#              ('Chad', 'Seychelles'): 1,
#              ('Chad', 'Sierra Leone'): 1,
#              ('Chad', 'Somalia'): 1,
#              ('Chad', 'Sudan'): 1,
#              ('Chad', 'Togo'): 1,
#              ('Chad', 'Tunisia'): 1,
#              ('Chad', 'Uganda'): 1,
#              ('Chad', 'United Republic of Tanzania'): 1,
#              ('Chad', 'Zambia'): 1,
#              ('Chad', 'Zimbabwe'): 1,
#              ('Comoros', 'Congo'): 2,
#              ('Comoros', "Cote d'Ivoire"): 1,
#              ('Comoros', 'Djibouti'): 2,
#              ('Comoros', 'Egypt'): 2,
#              ('Comoros', 'Equatorial Guinea'): 1,
#              ('Comoros', 'Ethiopia'): 2,
#              ('Comoros', 'Gabon'): 1,
#              ('Comoros', 'Gambia'): 1,
#              ('Comoros', 'Ghana'): 1,
#              ('Comoros', 'Guinea'): 1,
#              ('Comoros', 'Guinea-Bissau'): 1,
#              ('Comoros', 'Kenya'): 2,
#              ('Comoros', 'Lesotho'): 1,
#              ('Comoros', 'Liberia'): 1,
#              ('Comoros', 'Libya'): 1,
#              ('Comoros', 'Madagascar'): 2,
#              ('Comoros', 'Malawi'): 2,
#              ('Comoros', 'Mali'): 1,
#              ('Comoros', 'Mauritania'): 1,
#              ('Comoros', 'Mauritius'): 2,
#              ('Comoros', 'Mozambique'): 1,
#              ('Comoros', 'Namibia'): 2,
#              ('Comoros', 'Niger'): 1,
#              ('Comoros', 'Nigeria'): 1,
#              ('Comoros', 'Rwanda'): 2,
#              ('Comoros', 'Sao Tome and Principe'): 1,
#              ('Comoros', 'Senegal'): 1,
#              ('Comoros', 'Seychelles'): 2,
#              ('Comoros', 'Sierra Leone'): 1,
#              ('Comoros', 'Somalia'): 1,
#              ('Comoros', 'Sudan'): 2,
#              ('Comoros', 'Togo'): 1,
#              ('Comoros', 'Tunisia'): 1,
#              ('Comoros', 'Uganda'): 2,
#              ('Comoros', 'United Republic of Tanzania'): 2,
#              ('Comoros', 'Zambia'): 2,
#              ('Comoros', 'Zimbabwe'): 2,
#              ('Congo', "Cote d'Ivoire"): 1,
#              ('Congo', 'Djibouti'): 2,
#              ('Congo', 'Egypt'): 2,
#              ('Congo', 'Equatorial Guinea'): 2,
#              ('Congo', 'Ethiopia'): 2,
#              ('Congo', 'Gabon'): 2,
#              ('Congo', 'Gambia'): 1,
#              ('Congo', 'Ghana'): 1,
#              ('Congo', 'Guinea'): 1,
#              ('Congo', 'Guinea-Bissau'): 1,
#              ('Congo', 'Kenya'): 2,
#              ('Congo', 'Lesotho'): 2,
#              ('Congo', 'Liberia'): 1,
#              ('Congo', 'Libya'): 1,
#              ('Congo', 'Madagascar'): 2,
#              ('Congo', 'Malawi'): 3,
#              ('Congo', 'Mali'): 1,
#              ('Congo', 'Mauritania'): 1,
#              ('Congo', 'Mauritius'): 3,
#              ('Congo', 'Mozambique'): 2,
#              ('Congo', 'Namibia'): 3,
#              ('Congo', 'Niger'): 1,
#              ('Congo', 'Nigeria'): 1,
#              ('Congo', 'Rwanda'): 2,
#              ('Congo', 'Sao Tome and Principe'): 1,
#              ('Congo', 'Senegal'): 1,
#              ('Congo', 'Seychelles'): 3,
#              ('Congo', 'Sierra Leone'): 1,
#              ('Congo', 'Somalia'): 1,
#              ('Congo', 'Sudan'): 2,
#              ('Congo', 'Togo'): 1,
#              ('Congo', 'Tunisia'): 1,
#              ('Congo', 'Uganda'): 2,
#              ('Congo', 'United Republic of Tanzania'): 3,
#              ('Congo', 'Zambia'): 3,
#              ('Congo', 'Zimbabwe'): 3,
#              ("Cote d'Ivoire", 'Djibouti'): 1,
#              ("Cote d'Ivoire", 'Egypt'): 1,
#              ("Cote d'Ivoire", 'Equatorial Guinea'): 1,
#              ("Cote d'Ivoire", 'Ethiopia'): 1,
#              ("Cote d'Ivoire", 'Gabon'): 1,
#              ("Cote d'Ivoire", 'Gambia'): 2,
#              ("Cote d'Ivoire", 'Ghana'): 2,
#              ("Cote d'Ivoire", 'Guinea'): 2,
#              ("Cote d'Ivoire", 'Guinea-Bissau'): 2,
#              ("Cote d'Ivoire", 'Kenya'): 1,
#              ("Cote d'Ivoire", 'Lesotho'): 1,
#              ("Cote d'Ivoire", 'Liberia'): 2,
#              ("Cote d'Ivoire", 'Libya'): 1,
#              ("Cote d'Ivoire", 'Madagascar'): 1,
#              ("Cote d'Ivoire", 'Malawi'): 1,
#              ("Cote d'Ivoire", 'Mali'): 3,
#              ("Cote d'Ivoire", 'Mauritania'): 1,
#              ("Cote d'Ivoire", 'Mauritius'): 1,
#              ("Cote d'Ivoire", 'Mozambique'): 1,
#              ("Cote d'Ivoire", 'Namibia'): 1,
#              ("Cote d'Ivoire", 'Niger'): 3,
#              ("Cote d'Ivoire", 'Nigeria'): 2,
#              ("Cote d'Ivoire", 'Rwanda'): 1,
#              ("Cote d'Ivoire", 'Sao Tome and Principe'): 1,
#              ("Cote d'Ivoire", 'Senegal'): 3,
#              ("Cote d'Ivoire", 'Seychelles'): 1,
#              ("Cote d'Ivoire", 'Sierra Leone'): 2,
#              ("Cote d'Ivoire", 'Somalia'): 1,
#              ("Cote d'Ivoire", 'Sudan'): 1,
#              ("Cote d'Ivoire", 'Togo'): 3,
#              ("Cote d'Ivoire", 'Tunisia'): 1,
#              ("Cote d'Ivoire", 'Uganda'): 1,
#              ("Cote d'Ivoire", 'United Republic of Tanzania'): 1,
#              ("Cote d'Ivoire", 'Zambia'): 1,
#              ("Cote d'Ivoire", 'Zimbabwe'): 1,
#              ('Djibouti', 'Egypt'): 2,
#              ('Djibouti', 'Equatorial Guinea'): 1,
#              ('Djibouti', 'Ethiopia'): 3,
#              ('Djibouti', 'Gabon'): 1,
#              ('Djibouti', 'Gambia'): 1,
#              ('Djibouti', 'Ghana'): 1,
#              ('Djibouti', 'Guinea'): 1,
#              ('Djibouti', 'Guinea-Bissau'): 1,
#              ('Djibouti', 'Kenya'): 3,
#              ('Djibouti', 'Lesotho'): 1,
#              ('Djibouti', 'Liberia'): 1,
#              ('Djibouti', 'Libya'): 1,
#              ('Djibouti', 'Madagascar'): 2,
#              ('Djibouti', 'Malawi'): 2,
#              ('Djibouti', 'Mali'): 1,
#              ('Djibouti', 'Mauritania'): 1,
#              ('Djibouti', 'Mauritius'): 2,
#              ('Djibouti', 'Mozambique'): 1,
#              ('Djibouti', 'Namibia'): 2,
#              ('Djibouti', 'Niger'): 1,
#              ('Djibouti', 'Nigeria'): 1,
#              ('Djibouti', 'Rwanda'): 2,
#              ('Djibouti', 'Sao Tome and Principe'): 1,
#              ('Djibouti', 'Senegal'): 1,
#              ('Djibouti', 'Seychelles'): 2,
#              ('Djibouti', 'Sierra Leone'): 1,
#              ('Djibouti', 'Somalia'): 2,
#              ('Djibouti', 'Sudan'): 3,
#              ('Djibouti', 'Togo'): 1,
#              ('Djibouti', 'Tunisia'): 1,
#              ('Djibouti', 'Uganda'): 3,
#              ('Djibouti', 'United Republic of Tanzania'): 2,
#              ('Djibouti', 'Zambia'): 2,
#              ('Djibouti', 'Zimbabwe'): 2,
#              ('Egypt', 'Equatorial Guinea'): 1,
#              ('Egypt', 'Ethiopia'): 2,
#              ('Egypt', 'Gabon'): 1,
#              ('Egypt', 'Gambia'): 1,
#              ('Egypt', 'Ghana'): 2,
#              ('Egypt', 'Guinea'): 2,
#              ('Egypt', 'Guinea-Bissau'): 1,
#              ('Egypt', 'Kenya'): 2,
#              ('Egypt', 'Lesotho'): 1,
#              ('Egypt', 'Liberia'): 1,
#              ('Egypt', 'Libya'): 3,
#              ('Egypt', 'Madagascar'): 2,
#              ('Egypt', 'Malawi'): 2,
#              ('Egypt', 'Mali'): 1,
#              ('Egypt', 'Mauritania'): 1,
#              ('Egypt', 'Mauritius'): 2,
#              ('Egypt', 'Mozambique'): 2,
#              ('Egypt', 'Namibia'): 2,
#              ('Egypt', 'Niger'): 1,
#              ('Egypt', 'Nigeria'): 2,
#              ('Egypt', 'Rwanda'): 2,
#              ('Egypt', 'Sao Tome and Principe'): 1,
#              ('Egypt', 'Senegal'): 1,
#              ('Egypt', 'Seychelles'): 2,
#              ('Egypt', 'Sierra Leone'): 1,
#              ('Egypt', 'Somalia'): 1,
#              ('Egypt', 'Sudan'): 4,
#              ('Egypt', 'Togo'): 1,
#              ('Egypt', 'Tunisia'): 5,
#              ('Egypt', 'Uganda'): 2,
#              ('Egypt', 'United Republic of Tanzania'): 3,
#              ('Egypt', 'Zambia'): 2,
#              ('Egypt', 'Zimbabwe'): 3,
#              ('Equatorial Guinea', 'Ethiopia'): 1,
#              ('Equatorial Guinea', 'Gabon'): 3,
#              ('Equatorial Guinea', 'Gambia'): 1,
#              ('Equatorial Guinea', 'Ghana'): 1,
#              ('Equatorial Guinea', 'Guinea'): 1,
#              ('Equatorial Guinea', 'Guinea-Bissau'): 1,
#              ('Equatorial Guinea', 'Kenya'): 1,
#              ('Equatorial Guinea', 'Lesotho'): 1,
#              ('Equatorial Guinea', 'Liberia'): 1,
#              ('Equatorial Guinea', 'Libya'): 1,
#              ('Equatorial Guinea', 'Madagascar'): 1,
#              ('Equatorial Guinea', 'Malawi'): 1,
#              ('Equatorial Guinea', 'Mali'): 1,
#              ('Equatorial Guinea', 'Mauritania'): 1,
#              ('Equatorial Guinea', 'Mauritius'): 1,
#              ('Equatorial Guinea', 'Mozambique'): 1,
#              ('Equatorial Guinea', 'Namibia'): 1,
#              ('Equatorial Guinea', 'Niger'): 1,
#              ('Equatorial Guinea', 'Nigeria'): 1,
#              ('Equatorial Guinea', 'Rwanda'): 2,
#              ('Equatorial Guinea', 'Sao Tome and Principe'): 2,
#              ('Equatorial Guinea', 'Senegal'): 1,
#              ('Equatorial Guinea', 'Seychelles'): 1,
#              ('Equatorial Guinea', 'Sierra Leone'): 1,
#              ('Equatorial Guinea', 'Somalia'): 1,
#              ('Equatorial Guinea', 'Sudan'): 1,
#              ('Equatorial Guinea', 'Togo'): 1,
#              ('Equatorial Guinea', 'Tunisia'): 1,
#              ('Equatorial Guinea', 'Uganda'): 1,
#              ('Equatorial Guinea', 'United Republic of Tanzania'): 1,
#              ('Equatorial Guinea', 'Zambia'): 1,
#              ('Equatorial Guinea', 'Zimbabwe'): 1,
#              ('Ethiopia', 'Gabon'): 1,
#              ('Ethiopia', 'Gambia'): 1,
#              ('Ethiopia', 'Ghana'): 1,
#              ('Ethiopia', 'Guinea'): 1,
#              ('Ethiopia', 'Guinea-Bissau'): 1,
#              ('Ethiopia', 'Kenya'): 3,
#              ('Ethiopia', 'Lesotho'): 1,
#              ('Ethiopia', 'Liberia'): 1,
#              ('Ethiopia', 'Libya'): 1,
#              ('Ethiopia', 'Madagascar'): 2,
#              ('Ethiopia', 'Malawi'): 2,
#              ('Ethiopia', 'Mali'): 1,
#              ('Ethiopia', 'Mauritania'): 1,
#              ('Ethiopia', 'Mauritius'): 2,
#              ('Ethiopia', 'Mozambique'): 1,
#              ('Ethiopia', 'Namibia'): 2,
#              ('Ethiopia', 'Niger'): 1,
#              ('Ethiopia', 'Nigeria'): 1,
#              ('Ethiopia', 'Rwanda'): 2,
#              ('Ethiopia', 'Sao Tome and Principe'): 1,
#              ('Ethiopia', 'Senegal'): 1,
#              ('Ethiopia', 'Seychelles'): 2,
#              ('Ethiopia', 'Sierra Leone'): 1,
#              ('Ethiopia', 'Somalia'): 2,
#              ('Ethiopia', 'Sudan'): 3,
#              ('Ethiopia', 'Togo'): 1,
#              ('Ethiopia', 'Tunisia'): 1,
#              ('Ethiopia', 'Uganda'): 3,
#              ('Ethiopia', 'United Republic of Tanzania'): 2,
#              ('Ethiopia', 'Zambia'): 2,
#              ('Ethiopia', 'Zimbabwe'): 2,
#              ('Gabon', 'Gambia'): 1,
#              ('Gabon', 'Ghana'): 1,
#              ('Gabon', 'Guinea'): 1,
#              ('Gabon', 'Guinea-Bissau'): 1,
#              ('Gabon', 'Kenya'): 1,
#              ('Gabon', 'Lesotho'): 1,
#              ('Gabon', 'Liberia'): 1,
#              ('Gabon', 'Libya'): 1,
#              ('Gabon', 'Madagascar'): 1,
#              ('Gabon', 'Malawi'): 1,
#              ('Gabon', 'Mali'): 1,
#              ('Gabon', 'Mauritania'): 1,
#              ('Gabon', 'Mauritius'): 1,
#              ('Gabon', 'Mozambique'): 1,
#              ('Gabon', 'Namibia'): 1,
#              ('Gabon', 'Niger'): 1,
#              ('Gabon', 'Nigeria'): 1,
#              ('Gabon', 'Rwanda'): 2,
#              ('Gabon', 'Sao Tome and Principe'): 2,
#              ('Gabon', 'Senegal'): 1,
#              ('Gabon', 'Seychelles'): 1,
#              ('Gabon', 'Sierra Leone'): 1,
#              ('Gabon', 'Somalia'): 1,
#              ('Gabon', 'Sudan'): 1,
#              ('Gabon', 'Togo'): 1,
#              ('Gabon', 'Tunisia'): 1,
#              ('Gabon', 'Uganda'): 1,
#              ('Gabon', 'United Republic of Tanzania'): 1,
#              ('Gabon', 'Zambia'): 1,
#              ('Gabon', 'Zimbabwe'): 1,
#              ('Gambia', 'Ghana'): 2,
#              ('Gambia', 'Guinea'): 2,
#              ('Gambia', 'Guinea-Bissau'): 2,
#              ('Gambia', 'Kenya'): 1,
#              ('Gambia', 'Lesotho'): 1,
#              ('Gambia', 'Liberia'): 2,
#              ('Gambia', 'Libya'): 1,
#              ('Gambia', 'Madagascar'): 1,
#              ('Gambia', 'Malawi'): 1,
#              ('Gambia', 'Mali'): 2,
#              ('Gambia', 'Mauritania'): 1,
#              ('Gambia', 'Mauritius'): 1,
#              ('Gambia', 'Mozambique'): 1,
#              ('Gambia', 'Namibia'): 1,
#              ('Gambia', 'Niger'): 2,
#              ('Gambia', 'Nigeria'): 2,
#              ('Gambia', 'Rwanda'): 1,
#              ('Gambia', 'Sao Tome and Principe'): 1,
#              ('Gambia', 'Senegal'): 2,
#              ('Gambia', 'Seychelles'): 1,
#              ('Gambia', 'Sierra Leone'): 2,
#              ('Gambia', 'Somalia'): 1,
#              ('Gambia', 'Sudan'): 1,
#              ('Gambia', 'Togo'): 2,
#              ('Gambia', 'Tunisia'): 1,
#              ('Gambia', 'Uganda'): 1,
#              ('Gambia', 'United Republic of Tanzania'): 1,
#              ('Gambia', 'Zambia'): 1,
#              ('Gambia', 'Zimbabwe'): 1,
#              ('Ghana', 'Guinea'): 3,
#              ('Ghana', 'Guinea-Bissau'): 2,
#              ('Ghana', 'Kenya'): 1,
#              ('Ghana', 'Lesotho'): 1,
#              ('Ghana', 'Liberia'): 2,
#              ('Ghana', 'Libya'): 2,
#              ('Ghana', 'Madagascar'): 1,
#              ('Ghana', 'Malawi'): 1,
#              ('Ghana', 'Mali'): 2,
#              ('Ghana', 'Mauritania'): 1,
#              ('Ghana', 'Mauritius'): 1,
#              ('Ghana', 'Mozambique'): 2,
#              ('Ghana', 'Namibia'): 1,
#              ('Ghana', 'Niger'): 2,
#              ('Ghana', 'Nigeria'): 3,
#              ('Ghana', 'Rwanda'): 1,
#              ('Ghana', 'Sao Tome and Principe'): 1,
#              ('Ghana', 'Senegal'): 2,
#              ('Ghana', 'Seychelles'): 1,
#              ('Ghana', 'Sierra Leone'): 2,
#              ('Ghana', 'Somalia'): 1,
#              ('Ghana', 'Sudan'): 2,
#              ('Ghana', 'Togo'): 2,
#              ('Ghana', 'Tunisia'): 2,
#              ('Ghana', 'Uganda'): 1,
#              ('Ghana', 'United Republic of Tanzania'): 2,
#              ('Ghana', 'Zambia'): 1,
#              ('Ghana', 'Zimbabwe'): 2,
#              ('Guinea', 'Guinea-Bissau'): 2,
#              ('Guinea', 'Kenya'): 1,
#              ('Guinea', 'Lesotho'): 1,
#              ('Guinea', 'Liberia'): 2,
#              ('Guinea', 'Libya'): 2,
#              ('Guinea', 'Madagascar'): 1,
#              ('Guinea', 'Malawi'): 1,
#              ('Guinea', 'Mali'): 2,
#              ('Guinea', 'Mauritania'): 1,
#              ('Guinea', 'Mauritius'): 1,
#              ('Guinea', 'Mozambique'): 2,
#              ('Guinea', 'Namibia'): 1,
#              ('Guinea', 'Niger'): 2,
#              ('Guinea', 'Nigeria'): 3,
#              ('Guinea', 'Rwanda'): 1,
#              ('Guinea', 'Sao Tome and Principe'): 1,
#              ('Guinea', 'Senegal'): 2,
#              ('Guinea', 'Seychelles'): 1,
#              ('Guinea', 'Sierra Leone'): 2,
#              ('Guinea', 'Somalia'): 1,
#              ('Guinea', 'Sudan'): 2,
#              ('Guinea', 'Togo'): 2,
#              ('Guinea', 'Tunisia'): 2,
#              ('Guinea', 'Uganda'): 1,
#              ('Guinea', 'United Republic of Tanzania'): 2,
#              ('Guinea', 'Zambia'): 1,
#              ('Guinea', 'Zimbabwe'): 2,
#              ('Guinea-Bissau', 'Kenya'): 1,
#              ('Guinea-Bissau', 'Lesotho'): 1,
#              ('Guinea-Bissau', 'Liberia'): 2,
#              ('Guinea-Bissau', 'Libya'): 1,
#              ('Guinea-Bissau', 'Madagascar'): 1,
#              ('Guinea-Bissau', 'Malawi'): 1,
#              ('Guinea-Bissau', 'Mali'): 2,
#              ('Guinea-Bissau', 'Mauritania'): 1,
#              ('Guinea-Bissau', 'Mauritius'): 1,
#              ('Guinea-Bissau', 'Mozambique'): 1,
#              ('Guinea-Bissau', 'Namibia'): 1,
#              ('Guinea-Bissau', 'Niger'): 2,
#              ('Guinea-Bissau', 'Nigeria'): 2,
#              ('Guinea-Bissau', 'Rwanda'): 1,
#              ('Guinea-Bissau', 'Sao Tome and Principe'): 1,
#              ('Guinea-Bissau', 'Senegal'): 2,
#              ('Guinea-Bissau', 'Seychelles'): 1,
#              ('Guinea-Bissau', 'Sierra Leone'): 2,
#              ('Guinea-Bissau', 'Somalia'): 1,
#              ('Guinea-Bissau', 'Sudan'): 1,
#              ('Guinea-Bissau', 'Togo'): 2,
#              ('Guinea-Bissau', 'Tunisia'): 1,
#              ('Guinea-Bissau', 'Uganda'): 1,
#              ('Guinea-Bissau', 'United Republic of Tanzania'): 1,
#              ('Guinea-Bissau', 'Zambia'): 1,
#              ('Guinea-Bissau', 'Zimbabwe'): 1,
#              ('Kenya', 'Lesotho'): 1,
#              ('Kenya', 'Liberia'): 1,
#              ('Kenya', 'Libya'): 1,
#              ('Kenya', 'Madagascar'): 2,
#              ('Kenya', 'Malawi'): 2,
#              ('Kenya', 'Mali'): 1,
#              ('Kenya', 'Mauritania'): 1,
#              ('Kenya', 'Mauritius'): 2,
#              ('Kenya', 'Mozambique'): 1,
#              ('Kenya', 'Namibia'): 2,
#              ('Kenya', 'Niger'): 1,
#              ('Kenya', 'Nigeria'): 1,
#              ('Kenya', 'Rwanda'): 3,
#              ('Kenya', 'Sao Tome and Principe'): 1,
#              ('Kenya', 'Senegal'): 1,
#              ('Kenya', 'Seychelles'): 2,
#              ('Kenya', 'Sierra Leone'): 1,
#              ('Kenya', 'Somalia'): 2,
#              ('Kenya', 'Sudan'): 3,
#              ('Kenya', 'Togo'): 1,
#              ('Kenya', 'Tunisia'): 1,
#              ('Kenya', 'Uganda'): 4,
#              ('Kenya', 'United Republic of Tanzania'): 3,
#              ('Kenya', 'Zambia'): 2,
#              ('Kenya', 'Zimbabwe'): 2,
#              ('Lesotho', 'Liberia'): 1,
#              ('Lesotho', 'Libya'): 1,
#              ('Lesotho', 'Madagascar'): 1,
#              ('Lesotho', 'Malawi'): 3,
#              ('Lesotho', 'Mali'): 1,
#              ('Lesotho', 'Mauritania'): 1,
#              ('Lesotho', 'Mauritius'): 3,
#              ('Lesotho', 'Mozambique'): 3,
#              ('Lesotho', 'Namibia'): 5,
#              ('Lesotho', 'Niger'): 1,
#              ('Lesotho', 'Nigeria'): 1,
#              ('Lesotho', 'Rwanda'): 1,
#              ('Lesotho', 'Sao Tome and Principe'): 1,
#              ('Lesotho', 'Senegal'): 1,
#              ('Lesotho', 'Seychelles'): 2,
#              ('Lesotho', 'Sierra Leone'): 1,
#              ('Lesotho', 'Somalia'): 1,
#              ('Lesotho', 'Sudan'): 1,
#              ('Lesotho', 'Togo'): 1,
#              ('Lesotho', 'Tunisia'): 1,
#              ('Lesotho', 'Uganda'): 1,
#              ('Lesotho', 'United Republic of Tanzania'): 3,
#              ('Lesotho', 'Zambia'): 3,
#              ('Lesotho', 'Zimbabwe'): 3,
#              ('Liberia', 'Libya'): 1,
#              ('Liberia', 'Madagascar'): 1,
#              ('Liberia', 'Malawi'): 1,
#              ('Liberia', 'Mali'): 2,
#              ('Liberia', 'Mauritania'): 1,
#              ('Liberia', 'Mauritius'): 1,
#              ('Liberia', 'Mozambique'): 1,
#              ('Liberia', 'Namibia'): 1,
#              ('Liberia', 'Niger'): 2,
#              ('Liberia', 'Nigeria'): 2,
#              ('Liberia', 'Rwanda'): 1,
#              ('Liberia', 'Sao Tome and Principe'): 1,
#              ('Liberia', 'Senegal'): 2,
#              ('Liberia', 'Seychelles'): 1,
#              ('Liberia', 'Sierra Leone'): 3,
#              ('Liberia', 'Somalia'): 1,
#              ('Liberia', 'Sudan'): 1,
#              ('Liberia', 'Togo'): 2,
#              ('Liberia', 'Tunisia'): 1,
#              ('Liberia', 'Uganda'): 1,
#              ('Liberia', 'United Republic of Tanzania'): 1,
#              ('Liberia', 'Zambia'): 1,
#              ('Liberia', 'Zimbabwe'): 1,
#              ('Libya', 'Madagascar'): 1,
#              ('Libya', 'Malawi'): 1,
#              ('Libya', 'Mali'): 1,
#              ('Libya', 'Mauritania'): 2,
#              ('Libya', 'Mauritius'): 1,
#              ('Libya', 'Mozambique'): 2,
#              ('Libya', 'Namibia'): 1,
#              ('Libya', 'Niger'): 1,
#              ('Libya', 'Nigeria'): 2,
#              ('Libya', 'Rwanda'): 1,
#              ('Libya', 'Sao Tome and Principe'): 1,
#              ('Libya', 'Senegal'): 1,
#              ('Libya', 'Seychelles'): 1,
#              ('Libya', 'Sierra Leone'): 1,
#              ('Libya', 'Somalia'): 1,
#              ('Libya', 'Sudan'): 3,
#              ('Libya', 'Togo'): 1,
#              ('Libya', 'Tunisia'): 4,
#              ('Libya', 'Uganda'): 1,
#              ('Libya', 'United Republic of Tanzania'): 2,
#              ('Libya', 'Zambia'): 1,
#              ('Libya', 'Zimbabwe'): 2,
#              ('Madagascar', 'Malawi'): 2,
#              ('Madagascar', 'Mali'): 1,
#              ('Madagascar', 'Mauritania'): 1,
#              ('Madagascar', 'Mauritius'): 2,
#              ('Madagascar', 'Mozambique'): 1,
#              ('Madagascar', 'Namibia'): 2,
#              ('Madagascar', 'Niger'): 1,
#              ('Madagascar', 'Nigeria'): 1,
#              ('Madagascar', 'Rwanda'): 2,
#              ('Madagascar', 'Sao Tome and Principe'): 1,
#              ('Madagascar', 'Senegal'): 1,
#              ('Madagascar', 'Seychelles'): 2,
#              ('Madagascar', 'Sierra Leone'): 1,
#              ('Madagascar', 'Somalia'): 1,
#              ('Madagascar', 'Sudan'): 2,
#              ('Madagascar', 'Togo'): 1,
#              ('Madagascar', 'Tunisia'): 1,
#              ('Madagascar', 'Uganda'): 2,
#              ('Madagascar', 'United Republic of Tanzania'): 2,
#              ('Madagascar', 'Zambia'): 2,
#              ('Madagascar', 'Zimbabwe'): 2,
#              ('Malawi', 'Mali'): 1,
#              ('Malawi', 'Mauritania'): 1,
#              ('Malawi', 'Mauritius'): 4,
#              ('Malawi', 'Mozambique'): 3,
#              ('Malawi', 'Namibia'): 4,
#              ('Malawi', 'Niger'): 1,
#              ('Malawi', 'Nigeria'): 1,
#              ('Malawi', 'Rwanda'): 2,
#              ('Malawi', 'Sao Tome and Principe'): 1,
#              ('Malawi', 'Senegal'): 1,
#              ('Malawi', 'Seychelles'): 3,
#              ('Malawi', 'Sierra Leone'): 1,
#              ('Malawi', 'Somalia'): 1,
#              ('Malawi', 'Sudan'): 2,
#              ('Malawi', 'Togo'): 1,
#              ('Malawi', 'Tunisia'): 1,
#              ('Malawi', 'Uganda'): 2,
#              ('Malawi', 'United Republic of Tanzania'): 4,
#              ('Malawi', 'Zambia'): 4,
#              ('Malawi', 'Zimbabwe'): 4,
#              ('Mali', 'Mauritania'): 1,
#              ('Mali', 'Mauritius'): 1,
#              ('Mali', 'Mozambique'): 1,
#              ('Mali', 'Namibia'): 1,
#              ('Mali', 'Niger'): 3,
#              ('Mali', 'Nigeria'): 2,
#              ('Mali', 'Rwanda'): 1,
#              ('Mali', 'Sao Tome and Principe'): 1,
#              ('Mali', 'Senegal'): 3,
#              ('Mali', 'Seychelles'): 1,
#              ('Mali', 'Sierra Leone'): 2,
#              ('Mali', 'Somalia'): 1,
#              ('Mali', 'Sudan'): 1,
#              ('Mali', 'Togo'): 3,
#              ('Mali', 'Tunisia'): 1,
#              ('Mali', 'Uganda'): 1,
#              ('Mali', 'United Republic of Tanzania'): 1,
#              ('Mali', 'Zambia'): 1,
#              ('Mali', 'Zimbabwe'): 1,
#              ('Mauritania', 'Mauritius'): 1,
#              ('Mauritania', 'Mozambique'): 1,
#              ('Mauritania', 'Namibia'): 1,
#              ('Mauritania', 'Niger'): 1,
#              ('Mauritania', 'Nigeria'): 1,
#              ('Mauritania', 'Rwanda'): 1,
#              ('Mauritania', 'Sao Tome and Principe'): 1,
#              ('Mauritania', 'Senegal'): 1,
#              ('Mauritania', 'Seychelles'): 1,
#              ('Mauritania', 'Sierra Leone'): 1,
#              ('Mauritania', 'Somalia'): 1,
#              ('Mauritania', 'Sudan'): 1,
#              ('Mauritania', 'Togo'): 1,
#              ('Mauritania', 'Tunisia'): 2,
#              ('Mauritania', 'Uganda'): 1,
#              ('Mauritania', 'United Republic of Tanzania'): 1,
#              ('Mauritania', 'Zambia'): 1,
#              ('Mauritania', 'Zimbabwe'): 1,
#              ('Mauritius', 'Mozambique'): 3,
#              ('Mauritius', 'Namibia'): 4,
#              ('Mauritius', 'Niger'): 1,
#              ('Mauritius', 'Nigeria'): 1,
#              ('Mauritius', 'Rwanda'): 2,
#              ('Mauritius', 'Sao Tome and Principe'): 1,
#              ('Mauritius', 'Senegal'): 1,
#              ('Mauritius', 'Seychelles'): 3,
#              ('Mauritius', 'Sierra Leone'): 1,
#              ('Mauritius', 'Somalia'): 1,
#              ('Mauritius', 'Sudan'): 2,
#              ('Mauritius', 'Togo'): 1,
#              ('Mauritius', 'Tunisia'): 1,
#              ('Mauritius', 'Uganda'): 2,
#              ('Mauritius', 'United Republic of Tanzania'): 4,
#              ('Mauritius', 'Zambia'): 4,
#              ('Mauritius', 'Zimbabwe'): 4,
#              ('Mozambique', 'Namibia'): 3,
#              ('Mozambique', 'Niger'): 1,
#              ('Mozambique', 'Nigeria'): 2,
#              ('Mozambique', 'Rwanda'): 1,
#              ('Mozambique', 'Sao Tome and Principe'): 1,
#              ('Mozambique', 'Senegal'): 1,
#              ('Mozambique', 'Seychelles'): 2,
#              ('Mozambique', 'Sierra Leone'): 1,
#              ...})

# %%
trading_agreements = pd.DataFrame(edge_weights.items(), columns=["pair", "weight"])
trading_agreements[["src", "tgt"]] = trading_agreements.pair.apply(pd.Series)
trading_agreements.drop("pair", axis=1, inplace=True)

# %% [markdown]
# Make it both ways

# %%
trading_agreements_ = trading_agreements.copy()
trading_agreements_.rename({"src": "tgt", "tgt": "src"}, axis=1, inplace=True)

# %%
trading_agreements = pd.concat([trading_agreements, trading_agreements_], axis=0, ignore_index=True)

# %%
trading_agreements = trading_agreements.merge(countries_map[["country", "country_id"]], right_on="country", left_on="src", how="left")
trading_agreements.drop(["country", "src"], axis=1, inplace=True)
trading_agreements.rename({"country_id": "src"}, axis=1, inplace=True)

# %%
trading_agreements = trading_agreements.merge(countries_map[["country", "country_id"]], right_on="country", left_on="tgt", how="left")
trading_agreements.drop(["country", "tgt"], axis=1, inplace=True)
trading_agreements.rename({"country_id": "tgt"}, axis=1, inplace=True)

# %%
trading_agreements.head()

# %%
trading_agreements.to_csv(WRITE_DATA_PATHS["Graphs Data"] + "/trading_agreements_edges.csv", index=False)
