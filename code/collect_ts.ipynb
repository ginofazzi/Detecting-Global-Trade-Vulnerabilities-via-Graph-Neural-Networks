# %%
import os
import json

# %%
graph = "export"
ts = []

for seed in os.listdir(r"C:\Users\ginof\OneDrive\Documents\GitHub\Detecting-Global-Trade-Vulnerabilities-via-Graph-Neural-Networks\code\gnn\models\training\No Ablation\GAT\export"):
    for file in os.listdir(r"C:\Users\ginof\OneDrive\Documents\GitHub\Detecting-Global-Trade-Vulnerabilities-via-Graph-Neural-Networks\code\gnn\models\training\No Ablation\GAT\export" + f"\{seed}"):
        if file == "thresholds.json":
            folder = f"{seed}/{file}"
    print(folder)
# Out:
# 1
# 10
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
