# %%
import pandas as pd
import json
from scipy.stats import mannwhitneyu
import numpy as np

# %%
ablations = ['Ablation - COI', 'Ablation - ECI', 'Ablation - # Prod', "Ablation - SRCA", "Ablation - Geo-Positional", 'Ablation - HHI', "Ablation - TI", 
             'Ablation - Export Value', 'Ablation - Avg.PCI', 'Ablation - Trade Agreements', 'Ablation - Trustworthiness']
models = ['GCN', "GAT", "SAGE"]
graphs = ["export", "total", "export-layered", "multi-graph-total", "multi-graph-export"]

baseline = 'No Ablation'

i = 0

for ablation in ablations:

    for model in models:

        for graph in graphs:

            # These ablations are not applicable to certain graph types
            if ((ablation in ["Ablation - Trustworthiness"]) and (graph in ["export-layered", "total", "export"])) or \
            ((ablation in ["Ablation - SRCA", "Ablation - TI"]) and (graph in ["multi-graph-total", "multi-graph-export"])):
                continue

            ablation_results = []
            baseline_results = []

            for seed in range(1, 11):
                with open(f"results/{ablation}/{model}/{graph}/{seed}/report.json") as f:
                    _ = json.load(f)
                    ablation_results.append(_["F1 - Positives"])
                
                with open(f"results/{baseline}/{model}/{graph}/{seed}/report.json") as f:
                    baseline_results.append(json.load(f)["F1 - Positives"])
                
            stat, pvalue = mannwhitneyu(baseline_results, ablation_results)
            print(
                f"{ablation:<20} | {model:<6} | {graph:<20} | "
                f"Ablation: {np.mean(ablation_results):.4f} | "
                f"Baseline: {np.mean(baseline_results):.4f} | "
                f"Difference: {np.mean(ablation_results) - np.mean(baseline_results):.4f} | "
                f"p-value: {pvalue:.4f} {'(Significant)' if pvalue < (0.05/(len(ablations)*len(models)*len(graphs)-21)) else ''}"
            )
            i += 1

    print()
# Out:
# Ablation - COI       | GCN    | export               | Ablation: 0.1075 | Baseline: 0.1058 | Difference: 0.0018 | p-value: 0.1620
# Ablation - COI       | GCN    | total                | Ablation: 0.0977 | Baseline: 0.1168 | Difference: -0.0190 | p-value: 0.0028
# Ablation - COI       | GCN    | export-layered       | Ablation: 0.1002 | Baseline: 0.1025 | Difference: -0.0023 | p-value: 0.3447
# Ablation - COI       | GCN    | multi-graph-total    | Ablation: 0.9146 | Baseline: 0.9220 | Difference: -0.0074 | p-value: 0.0071
# Ablation - COI       | GCN    | multi-graph-export   | Ablation: 0.9214 | Baseline: 0.9165 | Difference: 0.0049 | p-value: 0.1298
# Ablation - COI       | GAT    | export               | Ablation: 0.1294 | Baseline: 0.1239 | Difference: 0.0055 | p-value: 0.5205
# Ablation - COI       | GAT    | total                | Ablation: 0.1331 | Baseline: 0.1307 | Difference: 0.0024 | p-value: 0.7913
# Ablation - COI       | GAT    | export-layered       | Ablation: 0.1064 | Baseline: 0.1153 | Difference: -0.0089 | p-value: 0.0257
# Ablation - COI       | GAT    | multi-graph-total    | Ablation: 0.9084 | Baseline: 0.9150 | Difference: -0.0066 | p-value: 1.0000
# Ablation - COI       | GAT    | multi-graph-export   | Ablation: 0.9134 | Baseline: 0.9119 | Difference: 0.0015 | p-value: 0.6229
# Ablation - COI       | SAGE   | export               | Ablation: 0.1208 | Baseline: 0.1247 | Difference: -0.0038 | p-value: 0.1405
# Ablation - COI       | SAGE   | total                | Ablation: 0.1015 | Baseline: 0.1264 | Difference: -0.0249 | p-value: 0.0002 (Significant)
# Ablation - COI       | SAGE   | export-layered       | Ablation: 0.1224 | Baseline: 0.1131 | Difference: 0.0093 | p-value: 0.0002 (Significant)
# Ablation - COI       | SAGE   | multi-graph-total    | Ablation: 0.8988 | Baseline: 0.9170 | Difference: -0.0182 | p-value: 0.0734
# Ablation - COI       | SAGE   | multi-graph-export   | Ablation: 0.8783 | Baseline: 0.9098 | Difference: -0.0316 | p-value: 0.0001 (Significant)
#
# Ablation - ECI       | GCN    | export               | Ablation: 0.1075 | Baseline: 0.1058 | Difference: 0.0018 | p-value: 0.1859
# Ablation - ECI       | GCN    | total                | Ablation: 0.0972 | Baseline: 0.1168 | Difference: -0.0196 | p-value: 0.0017
# Ablation - ECI       | GCN    | export-layered       | Ablation: 0.0888 | Baseline: 0.1025 | Difference: -0.0137 | p-value: 0.0003 (Significant)
# Ablation - ECI       | GCN    | multi-graph-total    | Ablation: 0.9251 | Baseline: 0.9220 | Difference: 0.0031 | p-value: 0.2478
# Ablation - ECI       | GCN    | multi-graph-export   | Ablation: 0.9163 | Baseline: 0.9165 | Difference: -0.0002 | p-value: 1.0000
# Ablation - ECI       | GAT    | export               | Ablation: 0.1183 | Baseline: 0.1239 | Difference: -0.0056 | p-value: 0.1405
# Ablation - ECI       | GAT    | total                | Ablation: 0.1253 | Baseline: 0.1307 | Difference: -0.0054 | p-value: 0.2730
# Ablation - ECI       | GAT    | export-layered       | Ablation: 0.1153 | Baseline: 0.1153 | Difference: 0.0000 | p-value: 0.9698
# Ablation - ECI       | GAT    | multi-graph-total    | Ablation: 0.9011 | Baseline: 0.9150 | Difference: -0.0139 | p-value: 0.2712
# Ablation - ECI       | GAT    | multi-graph-export   | Ablation: 0.9048 | Baseline: 0.9119 | Difference: -0.0071 | p-value: 0.5963
# Ablation - ECI       | SAGE   | export               | Ablation: 0.1096 | Baseline: 0.1247 | Difference: -0.0150 | p-value: 0.0211
# Ablation - ECI       | SAGE   | total                | Ablation: 0.1255 | Baseline: 0.1264 | Difference: -0.0009 | p-value: 0.7337
# Ablation - ECI       | SAGE   | export-layered       | Ablation: 0.1181 | Baseline: 0.1131 | Difference: 0.0051 | p-value: 0.0058
# Ablation - ECI       | SAGE   | multi-graph-total    | Ablation: 0.8825 | Baseline: 0.9170 | Difference: -0.0345 | p-value: 0.0006
# Ablation - ECI       | SAGE   | multi-graph-export   | Ablation: 0.8783 | Baseline: 0.9098 | Difference: -0.0316 | p-value: 0.0001 (Significant)
#
# Ablation - # Prod    | GCN    | export               | Ablation: 0.1068 | Baseline: 0.1058 | Difference: 0.0010 | p-value: 0.1620
# Ablation - # Prod    | GCN    | total                | Ablation: 0.1007 | Baseline: 0.1168 | Difference: -0.0161 | p-value: 0.0028
# Ablation - # Prod    | GCN    | export-layered       | Ablation: 0.1042 | Baseline: 0.1025 | Difference: 0.0017 | p-value: 0.1405
# Ablation - # Prod    | GCN    | multi-graph-total    | Ablation: 0.9251 | Baseline: 0.9220 | Difference: 0.0031 | p-value: 0.2478
# Ablation - # Prod    | GCN    | multi-graph-export   | Ablation: 0.9179 | Baseline: 0.9165 | Difference: 0.0014 | p-value: 0.4457
# Ablation - # Prod    | GAT    | export               | Ablation: 0.1306 | Baseline: 0.1239 | Difference: 0.0067 | p-value: 0.2730
# Ablation - # Prod    | GAT    | total                | Ablation: 0.1172 | Baseline: 0.1307 | Difference: -0.0136 | p-value: 0.0173
# Ablation - # Prod    | GAT    | export-layered       | Ablation: 0.1187 | Baseline: 0.1153 | Difference: 0.0034 | p-value: 0.1212
# Ablation - # Prod    | GAT    | multi-graph-total    | Ablation: 0.9121 | Baseline: 0.9150 | Difference: -0.0029 | p-value: 0.7333
# Ablation - # Prod    | GAT    | multi-graph-export   | Ablation: 0.8908 | Baseline: 0.9119 | Difference: -0.0211 | p-value: 0.0091
# Ablation - # Prod    | SAGE   | export               | Ablation: 0.1210 | Baseline: 0.1247 | Difference: -0.0036 | p-value: 0.1859
# Ablation - # Prod    | SAGE   | total                | Ablation: 0.1174 | Baseline: 0.1264 | Difference: -0.0090 | p-value: 0.0640
# Ablation - # Prod    | SAGE   | export-layered       | Ablation: 0.1234 | Baseline: 0.1131 | Difference: 0.0103 | p-value: 0.0002 (Significant)
# Ablation - # Prod    | SAGE   | multi-graph-total    | Ablation: 0.8831 | Baseline: 0.9170 | Difference: -0.0339 | p-value: 0.0008
# Ablation - # Prod    | SAGE   | multi-graph-export   | Ablation: 0.8822 | Baseline: 0.9098 | Difference: -0.0276 | p-value: 0.0012
#
# Ablation - SRCA      | GCN    | export               | Ablation: 0.1086 | Baseline: 0.1058 | Difference: 0.0029 | p-value: 0.0640
# Ablation - SRCA      | GCN    | total                | Ablation: 0.0914 | Baseline: 0.1168 | Difference: -0.0254 | p-value: 0.0452
# Ablation - SRCA      | GCN    | export-layered       | Ablation: 0.1076 | Baseline: 0.1025 | Difference: 0.0051 | p-value: 0.0013
# Ablation - SRCA      | GAT    | export               | Ablation: 0.1165 | Baseline: 0.1239 | Difference: -0.0074 | p-value: 0.0028
# Ablation - SRCA      | GAT    | total                | Ablation: 0.1107 | Baseline: 0.1307 | Difference: -0.0200 | p-value: 0.0046
# Ablation - SRCA      | GAT    | export-layered       | Ablation: 0.1197 | Baseline: 0.1153 | Difference: 0.0044 | p-value: 0.0757
# Ablation - SRCA      | SAGE   | export               | Ablation: 0.1181 | Baseline: 0.1247 | Difference: -0.0065 | p-value: 0.0539
# Ablation - SRCA      | SAGE   | total                | Ablation: 0.1200 | Baseline: 0.1264 | Difference: -0.0063 | p-value: 0.2413
# Ablation - SRCA      | SAGE   | export-layered       | Ablation: 0.1302 | Baseline: 0.1131 | Difference: 0.0171 | p-value: 0.0002 (Significant)
#
# Ablation - Geo-Positional | GCN    | export               | Ablation: 0.1179 | Baseline: 0.1058 | Difference: 0.0122 | p-value: 0.0013
# Ablation - Geo-Positional | GCN    | total                | Ablation: 0.0971 | Baseline: 0.1168 | Difference: -0.0197 | p-value: 0.0013
# Ablation - Geo-Positional | GCN    | export-layered       | Ablation: 0.0960 | Baseline: 0.1025 | Difference: -0.0064 | p-value: 0.1620
# Ablation - Geo-Positional | GCN    | multi-graph-total    | Ablation: 0.9221 | Baseline: 0.9220 | Difference: 0.0001 | p-value: 0.8197
# Ablation - Geo-Positional | GCN    | multi-graph-export   | Ablation: 0.9095 | Baseline: 0.9165 | Difference: -0.0070 | p-value: 0.0005
# Ablation - Geo-Positional | GAT    | export               | Ablation: 0.1275 | Baseline: 0.1239 | Difference: 0.0036 | p-value: 0.9698
# Ablation - Geo-Positional | GAT    | total                | Ablation: 0.1239 | Baseline: 0.1307 | Difference: -0.0069 | p-value: 0.1405
# Ablation - Geo-Positional | GAT    | export-layered       | Ablation: 0.1160 | Baseline: 0.1153 | Difference: 0.0007 | p-value: 1.0000
# Ablation - Geo-Positional | GAT    | multi-graph-total    | Ablation: 0.9045 | Baseline: 0.9150 | Difference: -0.0105 | p-value: 0.1506
# Ablation - Geo-Positional | GAT    | multi-graph-export   | Ablation: 0.8783 | Baseline: 0.9119 | Difference: -0.0336 | p-value: 0.0001 (Significant)
# Ablation - Geo-Positional | SAGE   | export               | Ablation: 0.1447 | Baseline: 0.1247 | Difference: 0.0201 | p-value: 0.0002 (Significant)
# Ablation - Geo-Positional | SAGE   | total                | Ablation: 0.1058 | Baseline: 0.1264 | Difference: -0.0206 | p-value: 0.0002 (Significant)
# Ablation - Geo-Positional | SAGE   | export-layered       | Ablation: 0.1195 | Baseline: 0.1131 | Difference: 0.0065 | p-value: 0.0058
# Ablation - Geo-Positional | SAGE   | multi-graph-total    | Ablation: 0.8900 | Baseline: 0.9170 | Difference: -0.0270 | p-value: 0.0061
# Ablation - Geo-Positional | SAGE   | multi-graph-export   | Ablation: 0.8783 | Baseline: 0.9098 | Difference: -0.0316 | p-value: 0.0001 (Significant)
#
# Ablation - HHI       | GCN    | export               | Ablation: 0.1028 | Baseline: 0.1058 | Difference: -0.0029 | p-value: 0.1405
# Ablation - HHI       | GCN    | total                | Ablation: 0.0949 | Baseline: 0.1168 | Difference: -0.0218 | p-value: 0.0003 (Significant)
# Ablation - HHI       | GCN    | export-layered       | Ablation: 0.1018 | Baseline: 0.1025 | Difference: -0.0007 | p-value: 0.9698
# Ablation - HHI       | GCN    | multi-graph-total    | Ablation: 0.9231 | Baseline: 0.9220 | Difference: 0.0012 | p-value: 0.9394
# Ablation - HHI       | GCN    | multi-graph-export   | Ablation: 0.9104 | Baseline: 0.9165 | Difference: -0.0061 | p-value: 0.0064
# Ablation - HHI       | GAT    | export               | Ablation: 0.1173 | Baseline: 0.1239 | Difference: -0.0066 | p-value: 0.2123
# Ablation - HHI       | GAT    | total                | Ablation: 0.1261 | Baseline: 0.1307 | Difference: -0.0046 | p-value: 0.5205
# Ablation - HHI       | GAT    | export-layered       | Ablation: 0.1177 | Baseline: 0.1153 | Difference: 0.0025 | p-value: 0.1405
# Ablation - HHI       | GAT    | multi-graph-total    | Ablation: 0.8783 | Baseline: 0.9150 | Difference: -0.0368 | p-value: 0.0001 (Significant)
# Ablation - HHI       | GAT    | multi-graph-export   | Ablation: 0.8864 | Baseline: 0.9119 | Difference: -0.0255 | p-value: 0.0018
# Ablation - HHI       | SAGE   | export               | Ablation: 0.1292 | Baseline: 0.1247 | Difference: 0.0046 | p-value: 0.2413
# Ablation - HHI       | SAGE   | total                | Ablation: 0.1261 | Baseline: 0.1264 | Difference: -0.0003 | p-value: 0.9097
# Ablation - HHI       | SAGE   | export-layered       | Ablation: 0.1224 | Baseline: 0.1131 | Difference: 0.0093 | p-value: 0.0008
# Ablation - HHI       | SAGE   | multi-graph-total    | Ablation: 0.8943 | Baseline: 0.9170 | Difference: -0.0227 | p-value: 0.0017
# Ablation - HHI       | SAGE   | multi-graph-export   | Ablation: 0.9017 | Baseline: 0.9098 | Difference: -0.0081 | p-value: 0.9093
#
# Ablation - TI        | GCN    | export               | Ablation: 0.1090 | Baseline: 0.1058 | Difference: 0.0033 | p-value: 0.2413
# Ablation - TI        | GCN    | total                | Ablation: 0.0967 | Baseline: 0.1168 | Difference: -0.0201 | p-value: 0.0013
# Ablation - TI        | GCN    | export-layered       | Ablation: 0.1046 | Baseline: 0.1025 | Difference: 0.0021 | p-value: 0.0452
# Ablation - TI        | GAT    | export               | Ablation: 0.1338 | Baseline: 0.1239 | Difference: 0.0099 | p-value: 0.1041
# Ablation - TI        | GAT    | total                | Ablation: 0.1193 | Baseline: 0.1307 | Difference: -0.0114 | p-value: 0.0890
# Ablation - TI        | GAT    | export-layered       | Ablation: 0.1090 | Baseline: 0.1153 | Difference: -0.0062 | p-value: 0.0073
# Ablation - TI        | SAGE   | export               | Ablation: 0.1365 | Baseline: 0.1247 | Difference: 0.0119 | p-value: 0.0312
# Ablation - TI        | SAGE   | total                | Ablation: 0.1138 | Baseline: 0.1264 | Difference: -0.0126 | p-value: 0.0022
# Ablation - TI        | SAGE   | export-layered       | Ablation: 0.1159 | Baseline: 0.1131 | Difference: 0.0028 | p-value: 0.1041
#
# Ablation - Export Value | GCN    | export               | Ablation: 0.1073 | Baseline: 0.1058 | Difference: 0.0015 | p-value: 0.1859
# Ablation - Export Value | GCN    | total                | Ablation: 0.0974 | Baseline: 0.1168 | Difference: -0.0194 | p-value: 0.0010
# Ablation - Export Value | GCN    | export-layered       | Ablation: 0.0952 | Baseline: 0.1025 | Difference: -0.0073 | p-value: 0.0036
# Ablation - Export Value | GCN    | multi-graph-total    | Ablation: 0.9217 | Baseline: 0.9220 | Difference: -0.0002 | p-value: 0.8191
# Ablation - Export Value | GCN    | multi-graph-export   | Ablation: 0.9216 | Baseline: 0.9165 | Difference: 0.0051 | p-value: 0.0371
# Ablation - Export Value | GAT    | export               | Ablation: 0.1252 | Baseline: 0.1239 | Difference: 0.0014 | p-value: 0.6776
# Ablation - Export Value | GAT    | total                | Ablation: 0.1276 | Baseline: 0.1307 | Difference: -0.0031 | p-value: 0.6776
# Ablation - Export Value | GAT    | export-layered       | Ablation: 0.1183 | Baseline: 0.1153 | Difference: 0.0031 | p-value: 0.3447
# Ablation - Export Value | GAT    | multi-graph-total    | Ablation: 0.9036 | Baseline: 0.9150 | Difference: -0.0114 | p-value: 0.4945
# Ablation - Export Value | GAT    | multi-graph-export   | Ablation: 0.9131 | Baseline: 0.9119 | Difference: 0.0012 | p-value: 0.8500
# Ablation - Export Value | SAGE   | export               | Ablation: 0.1212 | Baseline: 0.1247 | Difference: -0.0035 | p-value: 0.6776
# Ablation - Export Value | SAGE   | total                | Ablation: 0.1229 | Baseline: 0.1264 | Difference: -0.0034 | p-value: 0.4727
# Ablation - Export Value | SAGE   | export-layered       | Ablation: 0.1209 | Baseline: 0.1131 | Difference: 0.0079 | p-value: 0.1405
# Ablation - Export Value | SAGE   | multi-graph-total    | Ablation: 0.8783 | Baseline: 0.9170 | Difference: -0.0387 | p-value: 0.0001 (Significant)
# Ablation - Export Value | SAGE   | multi-graph-export   | Ablation: 0.9173 | Baseline: 0.9098 | Difference: 0.0075 | p-value: 0.0209
#
# Ablation - Avg.PCI   | GCN    | export               | Ablation: 0.1078 | Baseline: 0.1058 | Difference: 0.0020 | p-value: 0.1620
# Ablation - Avg.PCI   | GCN    | total                | Ablation: 0.0978 | Baseline: 0.1168 | Difference: -0.0190 | p-value: 0.0022
# Ablation - Avg.PCI   | GCN    | export-layered       | Ablation: 0.1000 | Baseline: 0.1025 | Difference: -0.0024 | p-value: 0.3075
# Ablation - Avg.PCI   | GCN    | multi-graph-total    | Ablation: 0.9254 | Baseline: 0.9220 | Difference: 0.0034 | p-value: 0.1311
# Ablation - Avg.PCI   | GCN    | multi-graph-export   | Ablation: 0.9221 | Baseline: 0.9165 | Difference: 0.0056 | p-value: 0.0254
# Ablation - Avg.PCI   | GAT    | export               | Ablation: 0.1264 | Baseline: 0.1239 | Difference: 0.0026 | p-value: 1.0000
# Ablation - Avg.PCI   | GAT    | total                | Ablation: 0.1241 | Baseline: 0.1307 | Difference: -0.0066 | p-value: 0.3075
# Ablation - Avg.PCI   | GAT    | export-layered       | Ablation: 0.1196 | Baseline: 0.1153 | Difference: 0.0044 | p-value: 0.0140
# Ablation - Avg.PCI   | GAT    | multi-graph-total    | Ablation: 0.8831 | Baseline: 0.9150 | Difference: -0.0320 | p-value: 0.0013
# Ablation - Avg.PCI   | GAT    | multi-graph-export   | Ablation: 0.9049 | Baseline: 0.9119 | Difference: -0.0070 | p-value: 0.7908
# Ablation - Avg.PCI   | SAGE   | export               | Ablation: 0.1213 | Baseline: 0.1247 | Difference: -0.0033 | p-value: 0.1405
# Ablation - Avg.PCI   | SAGE   | total                | Ablation: 0.1218 | Baseline: 0.1264 | Difference: -0.0046 | p-value: 0.3847
# Ablation - Avg.PCI   | SAGE   | export-layered       | Ablation: 0.1246 | Baseline: 0.1131 | Difference: 0.0115 | p-value: 0.0013
# Ablation - Avg.PCI   | SAGE   | multi-graph-total    | Ablation: 0.8783 | Baseline: 0.9170 | Difference: -0.0387 | p-value: 0.0001 (Significant)
# Ablation - Avg.PCI   | SAGE   | multi-graph-export   | Ablation: 0.9000 | Baseline: 0.9098 | Difference: -0.0099 | p-value: 0.8490
#
# Ablation - Trade Agreements | GCN    | export               | Ablation: 0.1076 | Baseline: 0.1058 | Difference: 0.0018 | p-value: 0.1859
# Ablation - Trade Agreements | GCN    | total                | Ablation: 0.0976 | Baseline: 0.1168 | Difference: -0.0191 | p-value: 0.0022
# Ablation - Trade Agreements | GCN    | export-layered       | Ablation: 0.1051 | Baseline: 0.1025 | Difference: 0.0027 | p-value: 0.0539
# Ablation - Trade Agreements | GCN    | multi-graph-total    | Ablation: 0.9175 | Baseline: 0.9220 | Difference: -0.0045 | p-value: 0.0131
# Ablation - Trade Agreements | GCN    | multi-graph-export   | Ablation: 0.9144 | Baseline: 0.9165 | Difference: -0.0021 | p-value: 0.4337
# Ablation - Trade Agreements | GAT    | export               | Ablation: 0.1330 | Baseline: 0.1239 | Difference: 0.0091 | p-value: 0.0312
# Ablation - Trade Agreements | GAT    | total                | Ablation: 0.1200 | Baseline: 0.1307 | Difference: -0.0107 | p-value: 0.0640
# Ablation - Trade Agreements | GAT    | export-layered       | Ablation: 0.1209 | Baseline: 0.1153 | Difference: 0.0057 | p-value: 0.0640
# Ablation - Trade Agreements | GAT    | multi-graph-total    | Ablation: 0.8824 | Baseline: 0.9150 | Difference: -0.0326 | p-value: 0.0010
# Ablation - Trade Agreements | GAT    | multi-graph-export   | Ablation: 0.9131 | Baseline: 0.9119 | Difference: 0.0012 | p-value: 0.2894
# Ablation - Trade Agreements | SAGE   | export               | Ablation: 0.1199 | Baseline: 0.1247 | Difference: -0.0047 | p-value: 0.0539
# Ablation - Trade Agreements | SAGE   | total                | Ablation: 0.1057 | Baseline: 0.1264 | Difference: -0.0207 | p-value: 0.0004
# Ablation - Trade Agreements | SAGE   | export-layered       | Ablation: 0.1171 | Baseline: 0.1131 | Difference: 0.0040 | p-value: 0.0376
# Ablation - Trade Agreements | SAGE   | multi-graph-total    | Ablation: 0.8783 | Baseline: 0.9170 | Difference: -0.0387 | p-value: 0.0001 (Significant)
# Ablation - Trade Agreements | SAGE   | multi-graph-export   | Ablation: 0.8783 | Baseline: 0.9098 | Difference: -0.0316 | p-value: 0.0001 (Significant)
#
# Ablation - Trustworthiness | GCN    | multi-graph-total    | Ablation: 0.9243 | Baseline: 0.9220 | Difference: 0.0023 | p-value: 0.3792
# Ablation - Trustworthiness | GCN    | multi-graph-export   | Ablation: 0.9109 | Baseline: 0.9165 | Difference: -0.0056 | p-value: 0.0207
# Ablation - Trustworthiness | GAT    | multi-graph-total    | Ablation: 0.9115 | Baseline: 0.9150 | Difference: -0.0036 | p-value: 0.7335
# Ablation - Trustworthiness | GAT    | multi-graph-export   | Ablation: 0.9079 | Baseline: 0.9119 | Difference: -0.0040 | p-value: 0.3445
# Ablation - Trustworthiness | SAGE   | multi-graph-total    | Ablation: 0.8783 | Baseline: 0.9170 | Difference: -0.0387 | p-value: 0.0001 (Significant)
# Ablation - Trustworthiness | SAGE   | multi-graph-export   | Ablation: 0.8783 | Baseline: 0.9098 | Difference: -0.0316 | p-value: 0.0001 (Significant)
